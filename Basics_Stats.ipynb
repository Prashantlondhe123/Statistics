# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantlondhe123/Statistics/blob/main/Basics_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basics Stats

# %% [markdown]
# ###Probability

# %% [markdown]
# -  Mean

# %% [markdown]
# >The mean is the average of a data set

# %% [markdown]
# - Mode

# %% [markdown]
# >The mode is the most common number in a data set

# %% [markdown]
# - Median

# %% [markdown]
# >The median is the middle of the set of numbers.

# %%
import numpy as np
from scipy import stats as st
l=[1,2,3,4,4,5,6]
print(np.mean(l))
print(np.median(l))
print(st.mode(l))
# Out:
# 3.5714285714285716
# 4.0
# ModeResult(mode=array([4]), count=array([2]))

# %% [markdown]
# - Standard Deviation

# %% [markdown]
# >Standard deviation is a number that describes how spread out the values are.

# %%
import numpy

speed = [86,87,88,86,87,85,86]

x = numpy.std(speed)

print(x)
# Out:
# 0.9035079029052513

# %% [markdown]
# -  Range

# %% [markdown]
# >  The difference between the largest value and the smallest value

# %% [markdown]
# -
